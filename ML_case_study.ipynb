# %% [markdown]
# # Name: Harsh, Prasad, Yashas #
# # Date: 03/18/2022 #

# %% [markdown]
# ## predicting who to approve and what should be the limit ##
#
# ### Execute the code from here ###

# %%
# !pip install shap

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mean
import matplotlib.pyplot as plt
from matplotlib import pyplot
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
import sklearn
from sklearn.preprocessing import PolynomialFeatures
import missingno as mi
from sklearn.linear_model import LogisticRegression
from statsmodels.stats.anova import anova_lm
import random
from statsmodels.formula.api import ols
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
import statistics
from sklearn.metrics import confusion_matrix
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import AlphaSelection
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import shap
from datetime import date

import pandas as pd
import numpy as np

import holoviews as hv
import plotly.graph_objects as go
import plotly.express as pex

import re

from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
import statsmodels.formula.api as smf
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import GridSearchCV, KFold

import xgboost as xgb

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#### reading the data set ####

data = pd.read_csv('/content/drive/MyDrive/ML - Team Project/case_study_data.csv')
data.head()
# Out:
#                    user_id   gender date_of_birth          workclass  \
# 0  307c73a3-0c67-43b5-b0d1   Female      03/01/87            Private
# 1  519481f1-604d-48b6-aa47     Male      07/01/70   Self-emp-not-inc
# 2  f66fe2c6-53e3-46ce-8321     Male      06/01/73            Private
# 3  91360ed7-72d1-4f6e-b492   Female      30/12/01            Private
# 4  0e1977f3-3bef-4283-8d0a     Male      03/01/86            Private
#
#   education_level  education_num       marital_status          occupation  \
# 0            11th              7        Never-married               Sales
# 1    Some-college             10   Married-civ-spouse        Craft-repair
# 2         HS-grad              9             Divorced               Sales
# 3            11th              7        Never-married               Sales
# 4    Some-college             10   Married-civ-spouse   Handlers-cleaners
#
#      relationship  capital_gain  ...  hours_per_week  approved  \
# 0       Unmarried             0  ...              17         0
# 1         Husband             0  ...              48         0
# 2   Not-in-family             0  ...              50         0
# 3       Own-child             0  ...              15         0
# 4         Husband             0  ...              50         0
#
#                                              address  \
# 0  45424 Norris Common Apt. 390\nNorth Mike, AR 8...
# 1  5022 Rebecca Haven Apt. 258\nThompsonfurt, CT ...
# 2    8780 Brown Loaf Apt. 099\nNorth David, NJ 56510
# 3  721 Jackson Extensions Suite 995\nNew Taraside...
# 4         935 Burch Divide\nLake Bobbyfurt, VT 14128
#
#                        email inquiry_purpose_code  institute_type  \
# 0      vasquezleah@yahoo.com                  7.0             PVT
# 1  johnsontrevor@hotmail.com                 13.0             NBF
# 2      morganemily@gmail.com                 13.0             NBF
# 3        agarcia@hotmail.com                 13.0             NBF
# 4  shermanmeredith@gmail.com                 13.0             PVT
#
#   account_type  asset_class_cd asset_code  portfolio_type
# 0            5             NaN        1.0               R
# 1            5             NaN        1.0               R
# 2            5             NaN        1.0               R
# 3            5             NaN        1.0               R
# 4           47               S        1.0               I
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45222 entries, 0 to 45221
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               45222 non-null  object
#  1   gender                45222 non-null  object
#  2   date_of_birth         45222 non-null  object
#  3   workclass             45222 non-null  object
#  4   education_level       45222 non-null  object
#  5   education_num         45222 non-null  int64
#  6   marital_status        45222 non-null  object
#  7   occupation            45222 non-null  object
#  8   relationship          45222 non-null  object
#  9   capital_gain          45222 non-null  int64
#  10  capital_loss          45222 non-null  int64
#  11  hours_per_week        45222 non-null  int64
#  12  approved              45222 non-null  int64
#  13  address               45222 non-null  object
#  14  email                 45222 non-null  object
#  15  inquiry_purpose_code  43931 non-null  float64
#  16  institute_type        45222 non-null  object
#  17  account_type          45222 non-null  int64
#  18  asset_class_cd        9492 non-null   object
#  19  asset_code            45140 non-null  float64
#  20  portfolio_type        45216 non-null  object
# dtypes: float64(2), int64(6), object(13)
# memory usage: 7.2+ MB

# %%
### columns in the dataset ###

data.columns
# Out:
# Index(['user_id', 'gender', 'date_of_birth', 'workclass', 'education_level',
#        'education_num', 'marital_status', 'occupation', 'relationship',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'approved', 'address',
#        'email', 'inquiry_purpose_code', 'institute_type', 'account_type',
#        'asset_class_cd', 'asset_code', 'portfolio_type'],
#       dtype='object')

# %%
### number of columns in the dataset ###

len(list(data.columns))
# Out:
# 21

# %%
#### checking null values in any of the columns ####

print(mi.bar(data.iloc[:,0:11], figsize = (15,5)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
## checking null values in rest of the columns ##

print(mi.bar(data.iloc[:,11:], figsize = (15,5)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# One of the columns (asset_class_cd) as only 20% non null values. Since, this number is way below the rule of thumb of 40%, we will not attempt to impute the values. If the number would have been closer to 40%, we would have created a predictive model to first predict the values of asset_class_cd and then use the predicted values to run the overall model. inquiry_purpose_code has about 3% null values. asset_code alos has some null values. We will check of they are distributed completely at random and if yes, we can remove them directly as it won't lead to reduction of large number of data points.

# %%
### removing the column ###

mod_data = data.drop(["asset_class_cd"], axis = 1)
mod_data.head(10)
# Out:
#                    user_id   gender date_of_birth          workclass  \
# 0  307c73a3-0c67-43b5-b0d1   Female      03/01/87            Private
# 1  519481f1-604d-48b6-aa47     Male      07/01/70   Self-emp-not-inc
# 2  f66fe2c6-53e3-46ce-8321     Male      06/01/73            Private
# 3  91360ed7-72d1-4f6e-b492   Female      30/12/01            Private
# 4  0e1977f3-3bef-4283-8d0a     Male      03/01/86            Private
# 5  3c8fbbaf-cd9d-4e17-8cd4   Female      11/01/56            Private
# 6  27256e97-6bae-4ce6-9b80   Female      30/12/01            Private
# 7  745b9022-fe0e-4d8e-8056   Female      31/12/96            Private
# 8  9b56df25-024a-47fe-b895     Male      05/01/77            Private
# 9  3257eeda-137c-4d8c-a295   Female      09/01/63          State-gov
#
#   education_level  education_num       marital_status          occupation  \
# 0            11th              7        Never-married               Sales
# 1    Some-college             10   Married-civ-spouse        Craft-repair
# 2         HS-grad              9             Divorced               Sales
# 3            11th              7        Never-married               Sales
# 4    Some-college             10   Married-civ-spouse   Handlers-cleaners
# 5         HS-grad              9              Widowed        Adm-clerical
# 6         HS-grad              9        Never-married               Sales
# 7    Some-college             10        Never-married     Farming-fishing
# 8         Masters             14   Married-civ-spouse     Exec-managerial
# 9            12th              8             Divorced       Other-service
#
#      relationship  capital_gain  capital_loss  hours_per_week  approved  \
# 0       Unmarried             0             0              17         0
# 1         Husband             0             0              48         0
# 2   Not-in-family             0             0              50         0
# 3       Own-child             0             0              15         0
# 4         Husband             0             0              50         0
# 5       Unmarried             0             0               8         0
# 6       Own-child             0             0              24         0
# 7   Not-in-family             0             0              50         0
# 8         Husband             0             0              45         0
# 9       Unmarried             0             0              40         0
#
#                                              address  \
# 0  45424 Norris Common Apt. 390\nNorth Mike, AR 8...
# 1  5022 Rebecca Haven Apt. 258\nThompsonfurt, CT ...
# 2    8780 Brown Loaf Apt. 099\nNorth David, NJ 56510
# 3  721 Jackson Extensions Suite 995\nNew Taraside...
# 4         935 Burch Divide\nLake Bobbyfurt, VT 14128
# 5          93533 Moore Greens\nWest Alicia, NC 34941
# 6  90598 Richardson Mountains Apt. 192\nJohnsonfu...
# 7  28328 Bradley Views Suite 367\nSmithport, AK 5...
# 8  47303 Sarah Freeway Suite 045\nLake Mariaborou...
# 9    7536 Davis Street Suite 960\nLuisfort, VA 25279
#
#                          email  inquiry_purpose_code institute_type  \
# 0        vasquezleah@yahoo.com                   7.0            PVT
# 1    johnsontrevor@hotmail.com                  13.0            NBF
# 2        morganemily@gmail.com                  13.0            NBF
# 3          agarcia@hotmail.com                  13.0            NBF
# 4    shermanmeredith@gmail.com                  13.0            PVT
# 5  frostvictor@west-barron.biz                  99.0            NBF
# 6         calvin66@hotmail.com                  14.0            HFC
# 7            bwalker@yahoo.com                  13.0            PVT
# 8           rperkins@yahoo.com                  10.0            PVT
# 9     emilymiller@martinez.com                   7.0            PVT
#
#    account_type  asset_code portfolio_type
# 0             5         1.0              R
# 1             5         1.0              R
# 2             5         1.0              R
# 3             5         1.0              R
# 4            47         1.0              I
# 5             5         1.0              R
# 6             5         1.0              R
# 7             5         1.0              R
# 8             5         1.0              R
# 9             5         1.0              R

# %% [markdown]
# 'inquiry_purpose_code' in the the data also has some null values but it only accounts for 3% of the overall data
# and hence, we can remove them but we first have to confirm that the data is missing completely at random

# %%
### visualizing the missing data in a inquiry_purpose_code and asset code ###

# %%
mi.matrix(mod_data)

# %% [markdown]
# There is no clear pattern in the missing data and hecen we can directly remove null values.

# %%
mod_data = mod_data[~pd.isna(mod_data['inquiry_purpose_code'])]
mod_data = mod_data[~pd.isna(mod_data['asset_code'])]

# %%
### checking the null values again ###

mi.matrix(mod_data)

# %% [markdown]
# ### exploratory data analysis ###

# %% [markdown]
# We have the address data but it's not usable in this current form. We can take zipcode out of it and try to use that in our analysis. Geographical location is can create biases in the data or may actually give sign whether the particular user will default or not.

# %%
mod_data['zipcode'] = list(("").join(list(i)[-5:]) for i in list(mod_data['address']))

# %% [markdown]
# We can extract the domain name from the email address.
# That might be one of the factors which can help us in predicting whether to approve or reject a user.

# %%
## if the domain name is not one of gmail, yahoo or hotmail, it's marked as others ##

mod_data['domain'] = list(re.search(r"(.*)@(.*)\.", i).group(2) for i in list(mod_data['email']))
mod_data['domain'] = list(i if i in ["gmail", "yahoo", "hotmail"] else "other" for i in list(mod_data['domain']))

# %% [markdown]
# We have the date of birth. From the date of birth, we can calculate the current age of the user.

# %%
### converting the dob column in required column ###

mod_data['date_of_birth'] = list(pd.to_datetime(i, format = "%d/%m/%y") for i in list(mod_data['date_of_birth']))
current_date = date(2022, 1, 25)

mod_data['age'] = list(((current_date - datetime.date(i)).days)/365 for i in list(mod_data['date_of_birth']))

### in some case, years like 1956 are being changed to 2056 ###
### taking care of that issue ###
mod_data['age'] = list(i if i >= 0 else i+100 for i in list(mod_data['age']))

# %%
## description of the data frame ##

mod_data.describe()
# Out:
#        education_num  capital_gain  capital_loss  hours_per_week  \
# count   43849.000000  43849.000000  43849.000000    43849.000000
# mean       10.120094   1119.200666     89.215946       40.939907
# std         2.555735   7609.215785    406.407564       12.015284
# min         1.000000      0.000000      0.000000        1.000000
# 25%         9.000000      0.000000      0.000000       40.000000
# 50%        10.000000      0.000000      0.000000       40.000000
# 75%        13.000000      0.000000      0.000000       45.000000
# max        16.000000  99999.000000   4356.000000       99.000000
#
#            approved  inquiry_purpose_code  account_type    asset_code  \
# count  43849.000000          43849.000000  43849.000000  43849.000000
# mean       0.249857             28.933613     80.720974      1.063377
# std        0.432935             35.390968    144.687443      0.705345
# min        0.000000              1.000000      5.000000      1.000000
# 25%        0.000000             13.000000      5.000000      1.000000
# 50%        0.000000             13.000000      5.000000      1.000000
# 75%        0.000000             16.000000    173.000000      1.000000
# max        1.000000             99.000000    999.000000     19.000000
#
#                 age
# count  43849.000000
# mean      40.640224
# std       13.195590
# min       19.084932
# 25%       30.084932
# 50%       39.084932
# 75%       49.084932
# max       92.016438

# %%
## we will now look at how diffeent columns are distributes ###

# %%
sns.pairplot(mod_data)

# %%
uni = mod_data.drop_duplicates(['user_id'], keep = "first")

len(list(uni.index)) == len(list(mod_data.index))
# Out:
# True

# %%
mod_data.corr()

## there is no clear high colinearity between the variables ##
# Out:
#                       education_num  capital_gain  capital_loss  \
# education_num              1.000000      0.127238      0.083101
# capital_gain               0.127238      1.000000     -0.032289
# capital_loss               0.083101     -0.032289      1.000000
# hours_per_week             0.146386      0.084251      0.055173
# approved                   0.333068      0.220460      0.149172
# inquiry_purpose_code       0.028970     -0.002066      0.006645
# account_type              -0.032596     -0.048366     -0.002758
# asset_code                -0.003463     -0.001447     -0.002735
# age                        0.038476      0.079905      0.060364
#
#                       hours_per_week  approved  inquiry_purpose_code  \
# education_num               0.146386  0.333068              0.028970
# capital_gain                0.084251  0.220460             -0.002066
# capital_loss                0.055173  0.149172              0.006645
# hours_per_week              1.000000  0.227841              0.013571
# approved                    0.227841  1.000000              0.085107
# inquiry_purpose_code        0.013571  0.085107              1.000000
# account_type               -0.022670 -0.058199             -0.063399
# asset_code                  0.005452  0.000795              0.006291
# age                         0.102559  0.238074              0.026184
#
#                       account_type  asset_code       age
# education_num            -0.032596   -0.003463  0.038476
# capital_gain             -0.048366   -0.001447  0.079905
# capital_loss             -0.002758   -0.002735  0.060364
# hours_per_week           -0.022670    0.005452  0.102559
# approved                 -0.058199    0.000795  0.238074
# inquiry_purpose_code     -0.063399    0.006291  0.026184
# account_type              1.000000    0.008458 -0.020554
# asset_code                0.008458    1.000000 -0.004445
# age                      -0.020554   -0.004445  1.000000

# %% [markdown]
# since the above condition is true, we know that we have data for unique user ids and hence,
# assume that each row correspond to a unique user.

# %% [markdown]
# we can't see clear pattern for particular variable transformations from the above chart.

# %%
mod_data.groupby(['approved'])['approved'].count()
# Out:
# approved
# 0    32893
# 1    10956
# Name: approved, dtype: int64

# %%
sns.histplot(x = "age", hue = "approved", data = mod_data)

# %% [markdown]
# It is clear from the above graph that users who are older are more likely to get approved.

# %%
ax = sns.factorplot(x='education_level', y='age', hue='approved', data=mod_data, kind='bar')
ax.set_xticklabels(rotation=65, horizontalalignment='right')
# Out:
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %% [markdown]
# From the above graph too, it is clear that in each education level,
# users who get approved are on average has a higher age.

# %%
ax = sns.factorplot(x='hours_per_week', y='age', hue='approved', data=mod_data, kind='point')
ax.set_xticklabels(label = None, rotation=65, horizontalalignment='right')
ax.set(xticklabels=[])
# Out:
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %% [markdown]
# Again, there is a clear pattern that age plays a major role in deciding who to approve and whom to decline.

# %%
ax = sns.factorplot(x='marital_status', y='age', hue='approved', data=mod_data, kind='point')
ax.set_xticklabels(label = None, rotation=65, horizontalalignment='right')
# Out:
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %% [markdown]
# Both approved and disapproved rates are higher in people who have atleast been married once (regardless of their
# current status). This may point towards human biases that might come into play while making such decisions.

# %%
ax = sns.factorplot(x='capital_gain', y='capital_loss', hue='approved', data=mod_data, kind='point')
ax.set_xticklabels(label = None, rotation=65, horizontalalignment='right')
ax.set(xticklabels=[])
# Out:
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
### trying to remove the outliers on age##

sns.boxplot(x = 'age', data = mod_data)

# %%
### we will remove the outliers based on the box plot ###
mod_data = mod_data[mod_data['age'] <= 78]

# %%
### trying to remove the outliers on capital gains ##

sns.boxplot(x = 'capital_gain', data = mod_data)

# %%
## removing outliers on capital gains ##
## we are being conservative in our approach as we don't want to remove too many points ##

mod_data = mod_data[mod_data['capital_gain'] <= 20000]

# %%
### trying to remove the outliers on capital loss ##

sns.boxplot(x = 'capital_loss', data = mod_data)

# %%
## removing outliers on capital loss ##
## we are being conservative in our approach as we don't want to remove too many points ##

mod_data = mod_data[mod_data['capital_loss'] <= 200]

# %%
### trying to remove the outliers on capital loss ##

sns.boxplot(x = 'hours_per_week', data = mod_data)

# %%
## removing outliers on hours per week ##
## we are being conservative in our approach as we don't want to remove too many points ##

mod_data = mod_data[mod_data['hours_per_week'] >= 20]
mod_data = mod_data[mod_data['hours_per_week'] <= 80]

# %%
### trying to remove the outliers on capital loss ##

sns.histplot(x = 'domain', data = mod_data)

# %% [markdown]
# Most of the users applying for the card has a personal domain not belonging
# to one of the giants.

# %%
### trying to remove the outliers on capital loss ##

sns.histplot(x = 'education_num', data = mod_data, hue = "approved")

# %% [markdown]
# We can clearly see from the above plot that as the education num increases, the percentage of
# users getting approved is also increasing.

# %%
### trying to remove the outliers on capital loss ##

ax = sns.histplot(x = 'education_level', data = mod_data, hue = "approved")
ax.set_xticklabels(mod_data['education_level'].unique(),rotation = 90)
# Out:
# [Text(0, 0, ' Some-college'),
#  Text(0, 0, ' HS-grad'),
#  Text(0, 0, ' Masters'),
#  Text(0, 0, ' 12th'),
#  Text(0, 0, ' Bachelors'),
#  Text(0, 0, ' Assoc-voc'),
#  Text(0, 0, ' Assoc-acdm'),
#  Text(0, 0, ' 9th'),
#  Text(0, 0, ' 7th-8th'),
#  Text(0, 0, ' 10th'),
#  Text(0, 0, ' Prof-school'),
#  Text(0, 0, ' 5th-6th'),
#  Text(0, 0, ' 11th'),
#  Text(0, 0, ' 1st-4th'),
#  Text(0, 0, ' Doctorate'),
#  Text(0, 0, ' Preschool')]

# %%
### capital gain vs education level ###

ax = sns.factorplot(y='capital_gain', x='education_level', hue='approved', data=mod_data, kind='point')
ax.set_xticklabels(label = None, rotation=65, horizontalalignment='right')
# Out:
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %% [markdown]
# It is clear from the above plot that as the education level increases, the average capital gain is increasing.

# %%
### capital gain vs education level

ax = sns.factorplot(y='capital_gain', x='institute_type', hue='approved', data=mod_data, kind='point')
ax.set_xticklabels(label = None, rotation=65, horizontalalignment='right')
# Out:
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %% [markdown]
# #### feature scaling ###
#
# We will try to scale all the features so that it doesn't affect the error function that we need to use.

# %%
mod_original = mod_data.copy(deep = True)

# %%
mod_data['age'] = (mod_data['age']-mod_data['age'].mean())/mod_data['age'].std()
mod_data['capital_gain'] = (mod_data['capital_gain']-mod_data['capital_gain'].mean())/mod_data['capital_gain'].std()
mod_data['capital_loss'] = (mod_data['capital_loss']-mod_data['capital_loss'].mean())/mod_data['capital_loss'].std()
mod_data['hours_per_week'] = (mod_data['hours_per_week']-mod_data['hours_per_week'].mean())/mod_data['hours_per_week'].std()

# %%
mod_data['gender'] = list(1 if i == "Male" else 0 for i in list(mod_data['gender']))

# %%
### making a copy of the data to be used later in logistic regression ###

dupl_mod_data = mod_data.copy(deep=True)

# %%
#### feature importance ####

# %% [markdown]
# A lot of ML models are hard to interpret and it is difficult to gauge the importance of each parameter in the model.
# To make the process of interpretation much easier, we will use a game theory library called Shapley Value Explanations. SHAP is used to provide a marginal importance numberto each paramter based on their importance. I am
# using the same model in my research to isolate important features.

# %%
### calculating SHAP values ###

# %%
# creating dummy variables for all the string variables so that they can be used in evaluating SHAP values ##

workclass = pd.get_dummies(mod_data['workclass'], drop_first = True)
education_level = pd.get_dummies(mod_data['education_level'], drop_first = True)
marital_status = pd.get_dummies(mod_data['marital_status'], drop_first = True)
occupation = pd.get_dummies(mod_data['occupation'], drop_first = True)
relationship = pd.get_dummies(mod_data['relationship'], drop_first = True)
inquiry_purpose_code = pd.get_dummies(mod_data['inquiry_purpose_code'], drop_first = True)
institute_type = pd.get_dummies(mod_data['institute_type'], drop_first = True)
account_type = pd.get_dummies(mod_data['account_type'], drop_first = True)
asset_code = pd.get_dummies(mod_data['asset_code'], drop_first = True)
portfolio_type = pd.get_dummies(mod_data['portfolio_type'], drop_first = True)
domain = pd.get_dummies(mod_data['domain'], drop_first = True)

mod_data.drop(['workclass', 'education_level', 'marital_status', 'occupation', 'relationship','inquiry_purpose_code', 'institute_type', 'account_type', 'asset_code', 'portfolio_type', 'domain'], axis = 1, inplace = True)

mod_data = pd.concat([mod_data, workclass, education_level, occupation,relationship, inquiry_purpose_code, institute_type,
                account_type, asset_code, portfolio_type, domain], axis = 1)

# %%
part_data = mod_data

X = mod_data.loc[:, mod_data.columns !=  'approved']
X = X.loc[:, X.columns !=  'user_id']
X = X.loc[:, X.columns !=  'email']
X = X.loc[:, X.columns !=  'zipcode']
X = X.loc[:, X.columns !=  'date_of_birth']
X = X.loc[:, X.columns !=  'address']
Y = mod_data['approved']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

masker = shap.maskers.Independent(data = X_test)


model = LogisticRegression(random_state=1, max_iter=1000).fit(X_train, y_train.values.ravel())

explainer = shap.LinearExplainer(model, masker=masker)
shap_values = explainer(X_test)
# Out:
# Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'int', 'str']. An error will be raised in 1.2.

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# From the above chart it is clear that relationships, education_num, marital_status, age, capital gains
# play the most major role in deciding what features to include. We will go from there and add variables
# in sort of forward step wise regression, i.e. once a variable has been added to the model, it will not be removed.

# %%
### running the first logistic regression model ###

formula = 'approved ~ age + education_num + capital_gain + C(relationship)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.351092
#          Iterations 8
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39086
# Method:                           MLE   Df Model:                            8
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.3605
# Time:                        07:16:28   Log-Likelihood:                -13726.
# converged:                       True   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ======================================================================================================
#                         approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -4.1915      0.076    -55.415      0.000      -4.340      -4.043
# C(relationship)[T. Not-in-family]     -2.2640      0.043    -52.292      0.000      -2.349      -2.179
# C(relationship)[T. Other-relative]    -2.6704      0.173    -15.396      0.000      -3.010      -2.330
# C(relationship)[T. Own-child]         -3.4346      0.119    -28.922      0.000      -3.667      -3.202
# C(relationship)[T. Unmarried]         -2.6274      0.075    -34.865      0.000      -2.775      -2.480
# C(relationship)[T. Wife]               0.1996      0.057      3.494      0.000       0.088       0.312
# age                                    0.3688      0.017     21.738      0.000       0.336       0.402
# education_num                          0.3665      0.007     52.891      0.000       0.353       0.380
# capital_gain                           0.7800      0.021     37.082      0.000       0.739       0.821
# ======================================================================================================
# AIC = 27469.86976608284

# %%
### adding one more independent variable to the above model ###

formula = 'approved ~ age + education_num + capital_gain + C(relationship) + C(education_level)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.350242
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39072
# Method:                           MLE   Df Model:                           22
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.3621
# Time:                        07:16:35   Log-Likelihood:                -13693.
# converged:                      False   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -3.8811        nan        nan        nan         nan         nan
# C(relationship)[T. Not-in-family]      -2.2748      0.044    -52.179      0.000      -2.360      -2.189
# C(relationship)[T. Other-relative]     -2.6823      0.174    -15.439      0.000      -3.023      -2.342
# C(relationship)[T. Own-child]          -3.4469      0.119    -29.011      0.000      -3.680      -3.214
# C(relationship)[T. Unmarried]          -2.6252      0.076    -34.748      0.000      -2.773      -2.477
# C(relationship)[T. Wife]                0.2062      0.057      3.603      0.000       0.094       0.318
# C(education_level)[T. 11th]            -0.1520        nan        nan        nan         nan         nan
# C(education_level)[T. 12th]             0.0121        nan        nan        nan         nan         nan
# C(education_level)[T. 1st-4th]          0.4786        nan        nan        nan         nan         nan
# C(education_level)[T. 5th-6th]          0.3512        nan        nan        nan         nan         nan
# C(education_level)[T. 7th-8th]          0.2804        nan        nan        nan         nan         nan
# C(education_level)[T. 9th]              0.0913        nan        nan        nan         nan         nan
# C(education_level)[T. Assoc-acdm]       0.1283        nan        nan        nan         nan         nan
# C(education_level)[T. Assoc-voc]        0.1647        nan        nan        nan         nan         nan
# C(education_level)[T. Bachelors]        0.4636        nan        nan        nan         nan         nan
# C(education_level)[T. Doctorate]        0.6291        nan        nan        nan         nan         nan
# C(education_level)[T. HS-grad]          0.1830        nan        nan        nan         nan         nan
# C(education_level)[T. Masters]          0.5630        nan        nan        nan         nan         nan
# C(education_level)[T. Preschool]       -0.1505        nan        nan        nan         nan         nan
# C(education_level)[T. Prof-school]      0.9725        nan        nan        nan         nan         nan
# C(education_level)[T. Some-college]     0.4137        nan        nan        nan         nan         nan
# age                                     0.3633      0.017     21.180      0.000       0.330       0.397
# education_num                           0.3070        nan        nan        nan         nan         nan
# capital_gain                            0.7824      0.021     37.117      0.000       0.741       0.824
# =======================================================================================================
# AIC = 27431.397974246713
# invalid value encountered in sqrt

# %% [markdown]
# All predictions of education_level are none and hence, it is of no use to us, we will remove it.

# %%
## adding another variable ###

formula = 'approved ~ age + education_num + capital_gain + C(relationship)  + C(occupation)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.340046
#          Iterations 9
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39073
# Method:                           MLE   Df Model:                           21
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.3807
# Time:                        07:16:38   Log-Likelihood:                -13294.
# converged:                       True   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -3.5252      0.103    -34.344      0.000      -3.726      -3.324
# C(relationship)[T. Not-in-family]      -2.2784      0.045    -51.091      0.000      -2.366      -2.191
# C(relationship)[T. Other-relative]     -2.5462      0.175    -14.564      0.000      -2.889      -2.204
# C(relationship)[T. Own-child]          -3.3582      0.120    -27.996      0.000      -3.593      -3.123
# C(relationship)[T. Unmarried]          -2.6207      0.077    -34.053      0.000      -2.772      -2.470
# C(relationship)[T. Wife]                0.2342      0.061      3.822      0.000       0.114       0.354
# C(occupation)[T. Armed-Forces]          0.8634      0.964      0.895      0.371      -1.027       2.753
# C(occupation)[T. Craft-repair]          0.0952      0.066      1.435      0.151      -0.035       0.225
# C(occupation)[T. Exec-managerial]       0.8578      0.064     13.504      0.000       0.733       0.982
# C(occupation)[T. Farming-fishing]      -0.9138      0.117     -7.806      0.000      -1.143      -0.684
# C(occupation)[T. Handlers-cleaners]    -0.6650      0.120     -5.563      0.000      -0.899      -0.431
# C(occupation)[T. Machine-op-inspct]    -0.2943      0.086     -3.441      0.001      -0.462      -0.127
# C(occupation)[T. Other-service]        -1.0129      0.102     -9.889      0.000      -1.214      -0.812
# C(occupation)[T. Priv-house-serv]      -1.5442      0.739     -2.090      0.037      -2.993      -0.096
# C(occupation)[T. Prof-specialty]        0.5553      0.066      8.363      0.000       0.425       0.685
# C(occupation)[T. Protective-serv]       0.5114      0.103      4.944      0.000       0.309       0.714
# C(occupation)[T. Sales]                 0.3130      0.068      4.617      0.000       0.180       0.446
# C(occupation)[T. Tech-support]          0.5023      0.094      5.347      0.000       0.318       0.686
# C(occupation)[T. Transport-moving]      0.0148      0.084      0.177      0.860      -0.149       0.179
# age                                     0.3556      0.017     20.364      0.000       0.321       0.390
# education_num                           0.2835      0.008     34.664      0.000       0.267       0.299
# capital_gain                            0.7777      0.021     36.226      0.000       0.736       0.820
# =======================================================================================================
# AIC = 26632.22550346411

# %% [markdown]
# AIC decreases again and there is also an increase in adjusted R2.

# %%
## adding another variable ###

formula = 'approved ~ age + education_num + capital_gain + C(relationship) + C(occupation) + C(institute_type)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.337611
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39064
# Method:                           MLE   Df Model:                           30
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.3851
# Time:                        07:16:41   Log-Likelihood:                -13199.
# converged:                      False   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -2.8662      0.200    -14.352      0.000      -3.258      -2.475
# C(relationship)[T. Not-in-family]      -2.2766      0.045    -50.899      0.000      -2.364      -2.189
# C(relationship)[T. Other-relative]     -2.5438      0.175    -14.539      0.000      -2.887      -2.201
# C(relationship)[T. Own-child]          -3.3547      0.120    -27.935      0.000      -3.590      -3.119
# C(relationship)[T. Unmarried]          -2.6277      0.077    -34.019      0.000      -2.779      -2.476
# C(relationship)[T. Wife]                0.2380      0.061      3.873      0.000       0.118       0.358
# C(occupation)[T. Armed-Forces]          0.8120      0.944      0.860      0.390      -1.038       2.662
# C(occupation)[T. Craft-repair]          0.1038      0.067      1.558      0.119      -0.027       0.234
# C(occupation)[T. Exec-managerial]       0.8667      0.064     13.596      0.000       0.742       0.992
# C(occupation)[T. Farming-fishing]      -0.9169      0.118     -7.799      0.000      -1.147      -0.686
# C(occupation)[T. Handlers-cleaners]    -0.6643      0.120     -5.541      0.000      -0.899      -0.429
# C(occupation)[T. Machine-op-inspct]    -0.2869      0.086     -3.344      0.001      -0.455      -0.119
# C(occupation)[T. Other-service]        -1.0016      0.103     -9.757      0.000      -1.203      -0.800
# C(occupation)[T. Priv-house-serv]      -1.4957      0.740     -2.022      0.043      -2.946      -0.046
# C(occupation)[T. Prof-specialty]        0.5590      0.067      8.388      0.000       0.428       0.690
# C(occupation)[T. Protective-serv]       0.5253      0.104      5.050      0.000       0.321       0.729
# C(occupation)[T. Sales]                 0.3309      0.068      4.866      0.000       0.198       0.464
# C(occupation)[T. Tech-support]          0.5081      0.094      5.378      0.000       0.323       0.693
# C(occupation)[T. Transport-moving]      0.0219      0.084      0.261      0.794      -0.143       0.187
# C(institute_type)[T.COB]                0.0663      0.571      0.116      0.908      -1.052       1.185
# C(institute_type)[T.FOR]               -0.3342      0.342     -0.977      0.328      -1.005       0.336
# C(institute_type)[T.HFC]               -0.9396      0.207     -4.549      0.000      -1.344      -0.535
# C(institute_type)[T.INS]               -0.5371      0.525     -1.023      0.306      -1.566       0.492
# C(institute_type)[T.NBF]               -0.9386      0.175     -5.371      0.000      -1.281      -0.596
# C(institute_type)[T.PUB]               -0.8109      0.196     -4.133      0.000      -1.195      -0.426
# C(institute_type)[T.PVT]               -0.5160      0.174     -2.970      0.003      -0.857      -0.175
# C(institute_type)[T.SRC]              -27.5706   1.22e+06  -2.26e-05      1.000   -2.39e+06    2.39e+06
# C(institute_type)[T.TEL]              -16.8599   2538.832     -0.007      0.995   -4992.879    4959.159
# age                                     0.3573      0.018     20.377      0.000       0.323       0.392
# education_num                           0.2837      0.008     34.546      0.000       0.268       0.300
# capital_gain                            0.7659      0.022     35.544      0.000       0.724       0.808
# =======================================================================================================
# AIC = 26459.833254259112

# %% [markdown]
# AIC decreases but -log likelihood increases and but since the drop in AIC is very significant.

# %%
## adding another variable ###

formula = 'approved ~ age + education_num + capital_gain + C(relationship)  + C(occupation) + C(institute_type) + C(domain)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.337530
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39061
# Method:                           MLE   Df Model:                           33
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.3852
# Time:                        07:16:45   Log-Likelihood:                -13196.
# converged:                      False   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -2.8447      0.203    -14.027      0.000      -3.242      -2.447
# C(relationship)[T. Not-in-family]      -2.2770      0.045    -50.900      0.000      -2.365      -2.189
# C(relationship)[T. Other-relative]     -2.5457      0.175    -14.547      0.000      -2.889      -2.203
# C(relationship)[T. Own-child]          -3.3555      0.120    -27.945      0.000      -3.591      -3.120
# C(relationship)[T. Unmarried]          -2.6268      0.077    -34.015      0.000      -2.778      -2.475
# C(relationship)[T. Wife]                0.2372      0.061      3.859      0.000       0.117       0.358
# C(occupation)[T. Armed-Forces]          0.8337      0.940      0.887      0.375      -1.008       2.675
# C(occupation)[T. Craft-repair]          0.1032      0.067      1.549      0.121      -0.027       0.234
# C(occupation)[T. Exec-managerial]       0.8677      0.064     13.606      0.000       0.743       0.993
# C(occupation)[T. Farming-fishing]      -0.9158      0.118     -7.789      0.000      -1.146      -0.685
# C(occupation)[T. Handlers-cleaners]    -0.6654      0.120     -5.549      0.000      -0.900      -0.430
# C(occupation)[T. Machine-op-inspct]    -0.2873      0.086     -3.348      0.001      -0.456      -0.119
# C(occupation)[T. Other-service]        -1.0020      0.103     -9.755      0.000      -1.203      -0.801
# C(occupation)[T. Priv-house-serv]      -1.5092      0.740     -2.039      0.041      -2.960      -0.058
# C(occupation)[T. Prof-specialty]        0.5611      0.067      8.415      0.000       0.430       0.692
# C(occupation)[T. Protective-serv]       0.5268      0.104      5.062      0.000       0.323       0.731
# C(occupation)[T. Sales]                 0.3311      0.068      4.867      0.000       0.198       0.464
# C(occupation)[T. Tech-support]          0.5112      0.095      5.409      0.000       0.326       0.696
# C(occupation)[T. Transport-moving]      0.0219      0.084      0.260      0.795      -0.143       0.187
# C(institute_type)[T.COB]                0.0693      0.572      0.121      0.904      -1.052       1.190
# C(institute_type)[T.FOR]               -0.3354      0.342     -0.980      0.327      -1.006       0.335
# C(institute_type)[T.HFC]               -0.9403      0.206     -4.554      0.000      -1.345      -0.536
# C(institute_type)[T.INS]               -0.5363      0.526     -1.021      0.307      -1.566       0.494
# C(institute_type)[T.NBF]               -0.9412      0.175     -5.386      0.000      -1.284      -0.599
# C(institute_type)[T.PUB]               -0.8151      0.196     -4.154      0.000      -1.200      -0.431
# C(institute_type)[T.PVT]               -0.5186      0.174     -2.985      0.003      -0.859      -0.178
# C(institute_type)[T.SRC]              -14.4812   1727.628     -0.008      0.993   -3400.571    3371.608
# C(institute_type)[T.TEL]              -15.7624   1444.712     -0.011      0.991   -2847.346    2815.821
# C(domain)[T.hotmail]                   -0.0497      0.054     -0.927      0.354      -0.155       0.055
# C(domain)[T.other]                      0.0134      0.043      0.308      0.758      -0.072       0.098
# C(domain)[T.yahoo]                     -0.0885      0.054     -1.650      0.099      -0.194       0.017
# age                                     0.3573      0.018     20.375      0.000       0.323       0.392
# education_num                           0.2834      0.008     34.504      0.000       0.267       0.300
# capital_gain                            0.7661      0.022     35.521      0.000       0.724       0.808
# =======================================================================================================
# AIC = 26459.46178312445

# %% [markdown]
# No such change in AIC value and hence, we will not include domain.

# %%
## adding another variable ###

formula = 'approved ~ age + education_num + capital_gain + C(relationship)  + C(occupation) + C(institute_type) + C(portfolio_type)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.337607
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39090
# Model:                        MNLogit   Df Residuals:                    39056
# Method:                           MLE   Df Model:                           33
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.3851
# Time:                        07:16:48   Log-Likelihood:                -13197.
# converged:                      False   LL-Null:                       -21462.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -5.0495      1.130     -4.469      0.000      -7.264      -2.835
# C(relationship)[T. Not-in-family]      -2.2766      0.045    -50.822      0.000      -2.364      -2.189
# C(relationship)[T. Other-relative]     -2.5515      0.175    -14.580      0.000      -2.894      -2.208
# C(relationship)[T. Own-child]          -3.3521      0.120    -27.922      0.000      -3.587      -3.117
# C(relationship)[T. Unmarried]          -2.6316      0.077    -34.068      0.000      -2.783      -2.480
# C(relationship)[T. Wife]                0.2432      0.062      3.951      0.000       0.123       0.364
# C(occupation)[T. Armed-Forces]          0.8258      0.944      0.875      0.381      -1.023       2.675
# C(occupation)[T. Craft-repair]          0.1031      0.067      1.546      0.122      -0.028       0.234
# C(occupation)[T. Exec-managerial]       0.8651      0.064     13.556      0.000       0.740       0.990
# C(occupation)[T. Farming-fishing]      -0.9189      0.118     -7.803      0.000      -1.150      -0.688
# C(occupation)[T. Handlers-cleaners]    -0.6663      0.120     -5.554      0.000      -0.901      -0.431
# C(occupation)[T. Machine-op-inspct]    -0.2871      0.086     -3.343      0.001      -0.455      -0.119
# C(occupation)[T. Other-service]        -1.0002      0.103     -9.737      0.000      -1.201      -0.799
# C(occupation)[T. Priv-house-serv]      -1.4905      0.740     -2.014      0.044      -2.941      -0.040
# C(occupation)[T. Prof-specialty]        0.5572      0.067      8.351      0.000       0.426       0.688
# C(occupation)[T. Protective-serv]       0.5315      0.104      5.105      0.000       0.327       0.736
# C(occupation)[T. Sales]                 0.3309      0.068      4.859      0.000       0.197       0.464
# C(occupation)[T. Tech-support]          0.5123      0.095      5.415      0.000       0.327       0.698
# C(occupation)[T. Transport-moving]      0.0193      0.084      0.229      0.819      -0.146       0.184
# C(institute_type)[T.COB]                0.0587      0.575      0.102      0.919      -1.068       1.185
# C(institute_type)[T.FOR]               -0.3586      0.343     -1.045      0.296      -1.031       0.314
# C(institute_type)[T.HFC]               -0.9878      0.209     -4.736      0.000      -1.397      -0.579
# C(institute_type)[T.INS]               -0.5336      0.523     -1.019      0.308      -1.560       0.492
# C(institute_type)[T.NBF]               -0.8908      0.175     -5.080      0.000      -1.235      -0.547
# C(institute_type)[T.PUB]               -0.8232      0.197     -4.172      0.000      -1.210      -0.436
# C(institute_type)[T.PVT]               -0.5093      0.174     -2.932      0.003      -0.850      -0.169
# C(institute_type)[T.SRC]               -9.7208    162.311     -0.060      0.952    -327.844     308.402
# C(institute_type)[T.TEL]               11.6634     35.729      0.326      0.744     -58.365      81.692
# C(portfolio_type)[T.I]                  2.0917      1.111      1.883      0.060      -0.086       4.269
# C(portfolio_type)[T.M]                  2.7643      1.115      2.480      0.013       0.580       4.949
# C(portfolio_type)[T.R]                  2.1798      1.111      1.962      0.050       0.002       4.358
# age                                     0.3579      0.018     20.391      0.000       0.323       0.392
# education_num                           0.2839      0.008     34.517      0.000       0.268       0.300
# capital_gain                            0.7641      0.022     35.327      0.000       0.722       0.806
# =======================================================================================================
# AIC = 26462.104717479953

# %% [markdown]
# AIC value increases and hence, we will not include portfolio type in our data.

# %%
## adding another variable ###

formula = 'approved ~ age + education_num + capital_gain + C(inquiry_purpose_code) + C(relationship)  + C(occupation) + C(institute_type)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.327300
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39047
# Method:                           MLE   Df Model:                           47
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.4039
# Time:                        07:16:51   Log-Likelihood:                -12796.
# converged:                      False   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -4.4230      0.312    -14.158      0.000      -5.035      -3.811
# C(inquiry_purpose_code)[T.2.0]          0.9355      0.248      3.769      0.000       0.449       1.422
# C(inquiry_purpose_code)[T.3.0]          0.4627      0.431      1.073      0.283      -0.382       1.308
# C(inquiry_purpose_code)[T.4.0]         -0.1990      0.785     -0.253      0.800      -1.738       1.340
# C(inquiry_purpose_code)[T.5.0]          1.2397      0.378      3.275      0.001       0.498       1.981
# C(inquiry_purpose_code)[T.6.0]          0.5197      0.289      1.800      0.072      -0.046       1.085
# C(inquiry_purpose_code)[T.7.0]          1.9045      0.240      7.924      0.000       1.433       2.375
# C(inquiry_purpose_code)[T.8.0]          0.9356      0.373      2.506      0.012       0.204       1.667
# C(inquiry_purpose_code)[T.9.0]          0.0655      1.239      0.053      0.958      -2.363       2.494
# C(inquiry_purpose_code)[T.10.0]        -0.1205      0.412     -0.293      0.770      -0.928       0.687
# C(inquiry_purpose_code)[T.11.0]        -0.0619      0.503     -0.123      0.902      -1.048       0.925
# C(inquiry_purpose_code)[T.12.0]         3.2897      1.246      2.641      0.008       0.848       5.731
# C(inquiry_purpose_code)[T.13.0]         0.8205      0.238      3.454      0.001       0.355       1.286
# C(inquiry_purpose_code)[T.14.0]         2.4113      0.257      9.374      0.000       1.907       2.916
# C(inquiry_purpose_code)[T.16.0]         1.0771      0.243      4.435      0.000       0.601       1.553
# C(inquiry_purpose_code)[T.17.0]         0.6404      0.949      0.675      0.500      -1.219       2.500
# C(inquiry_purpose_code)[T.18.0]       -40.6401   8.83e+08   -4.6e-08      1.000   -1.73e+09    1.73e+09
# C(inquiry_purpose_code)[T.99.0]         1.5784      0.239      6.606      0.000       1.110       2.047
# C(relationship)[T. Not-in-family]      -2.2704      0.045    -50.034      0.000      -2.359      -2.181
# C(relationship)[T. Other-relative]     -2.5619      0.176    -14.530      0.000      -2.907      -2.216
# C(relationship)[T. Own-child]          -3.3511      0.121    -27.724      0.000      -3.588      -3.114
# C(relationship)[T. Unmarried]          -2.6295      0.078    -33.676      0.000      -2.783      -2.476
# C(relationship)[T. Wife]                0.2457      0.063      3.914      0.000       0.123       0.369
# C(occupation)[T. Armed-Forces]          0.3888      0.985      0.395      0.693      -1.543       2.320
# C(occupation)[T. Craft-repair]          0.1052      0.068      1.553      0.120      -0.028       0.238
# C(occupation)[T. Exec-managerial]       0.8916      0.065     13.746      0.000       0.764       1.019
# C(occupation)[T. Farming-fishing]      -0.9173      0.119     -7.683      0.000      -1.151      -0.683
# C(occupation)[T. Handlers-cleaners]    -0.6557      0.122     -5.387      0.000      -0.894      -0.417
# C(occupation)[T. Machine-op-inspct]    -0.2755      0.087     -3.150      0.002      -0.447      -0.104
# C(occupation)[T. Other-service]        -1.0124      0.104     -9.717      0.000      -1.217      -0.808
# C(occupation)[T. Priv-house-serv]      -1.5959      0.753     -2.119      0.034      -3.072      -0.120
# C(occupation)[T. Prof-specialty]        0.5768      0.068      8.508      0.000       0.444       0.710
# C(occupation)[T. Protective-serv]       0.5608      0.106      5.302      0.000       0.353       0.768
# C(occupation)[T. Sales]                 0.3431      0.069      4.963      0.000       0.208       0.479
# C(occupation)[T. Tech-support]          0.5026      0.096      5.222      0.000       0.314       0.691
# C(occupation)[T. Transport-moving]      0.0170      0.086      0.199      0.842      -0.151       0.185
# C(institute_type)[T.COB]                1.0181      0.602      1.692      0.091      -0.161       2.198
# C(institute_type)[T.FOR]               -0.4476      0.345     -1.296      0.195      -1.124       0.229
# C(institute_type)[T.HFC]               -1.3439      0.215     -6.237      0.000      -1.766      -0.922
# C(institute_type)[T.INS]               -0.5514      0.526     -1.049      0.294      -1.581       0.479
# C(institute_type)[T.NBF]               -0.3213      0.178     -1.803      0.071      -0.671       0.028
# C(institute_type)[T.PUB]               -0.3639      0.209     -1.740      0.082      -0.774       0.046
# C(institute_type)[T.PVT]               -0.2773      0.176     -1.578      0.115      -0.622       0.067
# C(institute_type)[T.SRC]             -317.7238   1.06e+69     -3e-67      1.000   -2.08e+69    2.08e+69
# C(institute_type)[T.TEL]              -15.9163   1585.529     -0.010      0.992   -3123.497    3091.664
# age                                     0.3638      0.018     20.398      0.000       0.329       0.399
# education_num                           0.2806      0.008     33.572      0.000       0.264       0.297
# capital_gain                            0.7337      0.022     33.797      0.000       0.691       0.776
# =======================================================================================================
# AIC = 25687.589324186865

# %%
formula = 'approved ~ age + education_num + hours_per_week + capital_gain + C(inquiry_purpose_code) + C(relationship)  + C(occupation) + C(institute_type)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# overflow encountered in exp
# invalid value encountered in true_divide
# Optimization terminated successfully.
#          Current function value: nan
#          Iterations 15
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39046
# Method:                           MLE   Df Model:                           48
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                     nan
# Time:                        07:16:55   Log-Likelihood:                    nan
# converged:                       True   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                       nan
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                                  nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.2.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.3.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.4.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.5.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.6.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.7.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.8.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.9.0]             nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.10.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.11.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.12.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.13.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.14.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.16.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.17.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.18.0]            nan        nan        nan        nan         nan         nan
# C(inquiry_purpose_code)[T.99.0]            nan        nan        nan        nan         nan         nan
# C(relationship)[T. Not-in-family]          nan        nan        nan        nan         nan         nan
# C(relationship)[T. Other-relative]         nan        nan        nan        nan         nan         nan
# C(relationship)[T. Own-child]              nan        nan        nan        nan         nan         nan
# C(relationship)[T. Unmarried]              nan        nan        nan        nan         nan         nan
# C(relationship)[T. Wife]                   nan        nan        nan        nan         nan         nan
# C(occupation)[T. Armed-Forces]             nan        nan        nan        nan         nan         nan
# C(occupation)[T. Craft-repair]             nan        nan        nan        nan         nan         nan
# C(occupation)[T. Exec-managerial]          nan        nan        nan        nan         nan         nan
# C(occupation)[T. Farming-fishing]          nan        nan        nan        nan         nan         nan
# C(occupation)[T. Handlers-cleaners]        nan        nan        nan        nan         nan         nan
# C(occupation)[T. Machine-op-inspct]        nan        nan        nan        nan         nan         nan
# C(occupation)[T. Other-service]            nan        nan        nan        nan         nan         nan
# C(occupation)[T. Priv-house-serv]          nan        nan        nan        nan         nan         nan
# C(occupation)[T. Prof-specialty]           nan        nan        nan        nan         nan         nan
# C(occupation)[T. Protective-serv]          nan        nan        nan        nan         nan         nan
# C(occupation)[T. Sales]                    nan        nan        nan        nan         nan         nan
# C(occupation)[T. Tech-support]             nan        nan        nan        nan         nan         nan
# C(occupation)[T. Transport-moving]         nan        nan        nan        nan         nan         nan
# C(institute_type)[T.COB]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.FOR]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.HFC]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.INS]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.NBF]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.PUB]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.PVT]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.SRC]                   nan        nan        nan        nan         nan         nan
# C(institute_type)[T.TEL]                   nan        nan        nan        nan         nan         nan
# age                                        nan        nan        nan        nan         nan         nan
# education_num                              nan        nan        nan        nan         nan         nan
# hours_per_week                             nan        nan        nan        nan         nan         nan
# capital_gain                               nan        nan        nan        nan         nan         nan
# =======================================================================================================
# AIC = nan

# %% [markdown]
# Hours per week is not giving meaningful results and hence, we will not include that in our model.

# %%
formula = 'approved ~ age + education_num + capital_gain + capital_loss + C(inquiry_purpose_code) + C(relationship)  + C(occupation) + C(institute_type)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.327300
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39046
# Method:                           MLE   Df Model:                           48
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.4039
# Time:                        07:17:00   Log-Likelihood:                -12796.
# converged:                      False   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                          approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -4.4235     13.753     -0.322      0.748     -31.379      22.532
# C(inquiry_purpose_code)[T.2.0]          0.9355      0.248      3.769      0.000       0.449       1.422
# C(inquiry_purpose_code)[T.3.0]          0.4627      0.431      1.073      0.283      -0.382       1.308
# C(inquiry_purpose_code)[T.4.0]         -0.1990      0.785     -0.253      0.800      -1.738       1.340
# C(inquiry_purpose_code)[T.5.0]          1.2397      0.378      3.275      0.001       0.498       1.981
# C(inquiry_purpose_code)[T.6.0]          0.5197      0.289      1.800      0.072      -0.046       1.085
# C(inquiry_purpose_code)[T.7.0]          1.9044      0.240      7.924      0.000       1.433       2.375
# C(inquiry_purpose_code)[T.8.0]          0.9356      0.373      2.506      0.012       0.204       1.667
# C(inquiry_purpose_code)[T.9.0]          0.0655      1.239      0.053      0.958      -2.363       2.494
# C(inquiry_purpose_code)[T.10.0]        -0.1205      0.412     -0.293      0.770      -0.928       0.687
# C(inquiry_purpose_code)[T.11.0]        -0.0619      0.503     -0.123      0.902      -1.048       0.925
# C(inquiry_purpose_code)[T.12.0]         3.2897      1.246      2.641      0.008       0.848       5.731
# C(inquiry_purpose_code)[T.13.0]         0.8205      0.238      3.454      0.001       0.355       1.286
# C(inquiry_purpose_code)[T.14.0]         2.4113      0.257      9.374      0.000       1.907       2.916
# C(inquiry_purpose_code)[T.16.0]         1.0771      0.243      4.435      0.000       0.601       1.553
# C(inquiry_purpose_code)[T.17.0]         0.6404      0.949      0.675      0.500      -1.219       2.500
# C(inquiry_purpose_code)[T.18.0]       -36.6334   1.19e+08  -3.08e-07      1.000   -2.33e+08    2.33e+08
# C(inquiry_purpose_code)[T.99.0]         1.5784      0.239      6.606      0.000       1.110       2.047
# C(relationship)[T. Not-in-family]      -2.2703      0.045    -50.034      0.000      -2.359      -2.181
# C(relationship)[T. Other-relative]     -2.5619      0.176    -14.530      0.000      -2.907      -2.216
# C(relationship)[T. Own-child]          -3.3511      0.121    -27.724      0.000      -3.588      -3.114
# C(relationship)[T. Unmarried]          -2.6295      0.078    -33.676      0.000      -2.782      -2.476
# C(relationship)[T. Wife]                0.2457      0.063      3.914      0.000       0.123       0.369
# C(occupation)[T. Armed-Forces]          0.3888      0.985      0.395      0.693      -1.543       2.320
# C(occupation)[T. Craft-repair]          0.1052      0.068      1.553      0.120      -0.028       0.238
# C(occupation)[T. Exec-managerial]       0.8916      0.065     13.746      0.000       0.764       1.019
# C(occupation)[T. Farming-fishing]      -0.9173      0.119     -7.683      0.000      -1.151      -0.683
# C(occupation)[T. Handlers-cleaners]    -0.6557      0.122     -5.387      0.000      -0.894      -0.417
# C(occupation)[T. Machine-op-inspct]    -0.2755      0.087     -3.149      0.002      -0.447      -0.104
# C(occupation)[T. Other-service]        -1.0124      0.104     -9.717      0.000      -1.217      -0.808
# C(occupation)[T. Priv-house-serv]      -1.5959      0.753     -2.119      0.034      -3.072      -0.120
# C(occupation)[T. Prof-specialty]        0.5768      0.068      8.509      0.000       0.444       0.710
# C(occupation)[T. Protective-serv]       0.5608      0.106      5.302      0.000       0.353       0.768
# C(occupation)[T. Sales]                 0.3431      0.069      4.963      0.000       0.208       0.479
# C(occupation)[T. Tech-support]          0.5026      0.096      5.222      0.000       0.314       0.691
# C(occupation)[T. Transport-moving]      0.0170      0.086      0.199      0.842      -0.151       0.185
# C(institute_type)[T.COB]                1.0181      0.602      1.692      0.091      -0.161       2.198
# C(institute_type)[T.FOR]               -0.4476      0.345     -1.296      0.195      -1.124       0.229
# C(institute_type)[T.HFC]               -1.3439      0.215     -6.237      0.000      -1.766      -0.922
# C(institute_type)[T.INS]               -0.5514      0.526     -1.049      0.294      -1.581       0.479
# C(institute_type)[T.NBF]               -0.3213      0.178     -1.803      0.071      -0.671       0.028
# C(institute_type)[T.PUB]               -0.3639      0.209     -1.740      0.082      -0.774       0.046
# C(institute_type)[T.PVT]               -0.2773      0.176     -1.578      0.115      -0.622       0.067
# C(institute_type)[T.SRC]             -317.6347   1.01e+69  -3.13e-67      1.000   -1.99e+69    1.99e+69
# C(institute_type)[T.TEL]              -15.7095   1429.823     -0.011      0.991   -2818.111    2786.692
# age                                     0.3638      0.018     20.398      0.000       0.329       0.399
# education_num                           0.2806      0.008     33.572      0.000       0.264       0.297
# capital_gain                            0.7337      0.022     33.797      0.000       0.691       0.776
# capital_loss                           -0.1070   2718.664  -3.94e-05      1.000   -5328.590    5328.376
# =======================================================================================================
# AIC = 25689.578581720023

# %% [markdown]
# AIC increases for capital loss and hence won't be included in our model.

# %% [markdown]
# ### This is the final model.

# %%
formula = 'approved ~ age + education_num + capital_gain + C(inquiry_purpose_code) + C(relationship)  + C(occupation) + C(institute_type) + C(marital_status)'
fit = smf.mnlogit(formula=formula, data=dupl_mod_data).fit()
print(fit.summary())

print("AIC =", str(fit.aic))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.325658
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                39095
# Model:                        MNLogit   Df Residuals:                    39041
# Method:                           MLE   Df Model:                           53
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.4069
# Time:                        07:17:14   Log-Likelihood:                -12732.
# converged:                      False   LL-Null:                       -21465.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===============================================================================================================
#                                  approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                      -6.7794      0.394    -17.200      0.000      -7.552      -6.007
# C(inquiry_purpose_code)[T.2.0]                  0.9361      0.248      3.769      0.000       0.449       1.423
# C(inquiry_purpose_code)[T.3.0]                  0.4466      0.432      1.034      0.301      -0.400       1.293
# C(inquiry_purpose_code)[T.4.0]                 -0.1936      0.787     -0.246      0.806      -1.735       1.348
# C(inquiry_purpose_code)[T.5.0]                  1.2280      0.378      3.249      0.001       0.487       1.969
# C(inquiry_purpose_code)[T.6.0]                  0.5231      0.289      1.811      0.070      -0.043       1.089
# C(inquiry_purpose_code)[T.7.0]                  1.9043      0.240      7.919      0.000       1.433       2.376
# C(inquiry_purpose_code)[T.8.0]                  0.9443      0.374      2.527      0.012       0.212       1.677
# C(inquiry_purpose_code)[T.9.0]                  0.0799      1.242      0.064      0.949      -2.354       2.514
# C(inquiry_purpose_code)[T.10.0]                -0.1195      0.413     -0.290      0.772      -0.928       0.689
# C(inquiry_purpose_code)[T.11.0]                -0.0463      0.504     -0.092      0.927      -1.035       0.942
# C(inquiry_purpose_code)[T.12.0]                 3.2243      1.256      2.567      0.010       0.763       5.686
# C(inquiry_purpose_code)[T.13.0]                 0.8222      0.238      3.459      0.001       0.356       1.288
# C(inquiry_purpose_code)[T.14.0]                 2.4198      0.258      9.395      0.000       1.915       2.925
# C(inquiry_purpose_code)[T.16.0]                 1.0811      0.243      4.449      0.000       0.605       1.557
# C(inquiry_purpose_code)[T.17.0]                 0.6658      0.955      0.697      0.486      -1.206       2.538
# C(inquiry_purpose_code)[T.18.0]               -15.1969   2648.102     -0.006      0.995   -5205.381    5174.988
# C(inquiry_purpose_code)[T.99.0]                 1.5797      0.239      6.608      0.000       1.111       2.048
# C(relationship)[T. Not-in-family]               0.2528      0.234      1.081      0.280      -0.206       0.711
# C(relationship)[T. Other-relative]             -0.9293      0.213     -4.360      0.000      -1.347      -0.512
# C(relationship)[T. Own-child]                  -0.9640      0.228     -4.223      0.000      -1.411      -0.517
# C(relationship)[T. Unmarried]                  -0.2138      0.246     -0.869      0.385      -0.696       0.268
# C(relationship)[T. Wife]                        0.2338      0.063      3.717      0.000       0.111       0.357
# C(occupation)[T. Armed-Forces]                  0.2302      0.970      0.237      0.812      -1.670       2.131
# C(occupation)[T. Craft-repair]                  0.0952      0.068      1.404      0.160      -0.038       0.228
# C(occupation)[T. Exec-managerial]               0.8829      0.065     13.586      0.000       0.756       1.010
# C(occupation)[T. Farming-fishing]              -0.9116      0.119     -7.630      0.000      -1.146      -0.677
# C(occupation)[T. Handlers-cleaners]            -0.6602      0.122     -5.418      0.000      -0.899      -0.421
# C(occupation)[T. Machine-op-inspct]            -0.2831      0.088     -3.234      0.001      -0.455      -0.112
# C(occupation)[T. Other-service]                -1.0187      0.104     -9.766      0.000      -1.223      -0.814
# C(occupation)[T. Priv-house-serv]              -1.7285      0.751     -2.303      0.021      -3.200      -0.257
# C(occupation)[T. Prof-specialty]                0.5804      0.068      8.534      0.000       0.447       0.714
# C(occupation)[T. Protective-serv]               0.5449      0.106      5.158      0.000       0.338       0.752
# C(occupation)[T. Sales]                         0.3384      0.069      4.885      0.000       0.203       0.474
# C(occupation)[T. Tech-support]                  0.5083      0.097      5.261      0.000       0.319       0.698
# C(occupation)[T. Transport-moving]              0.0096      0.086      0.112      0.911      -0.158       0.177
# C(institute_type)[T.COB]                        1.0096      0.601      1.679      0.093      -0.169       2.188
# C(institute_type)[T.FOR]                       -0.4160      0.346     -1.202      0.229      -1.094       0.262
# C(institute_type)[T.HFC]                       -1.3341      0.215     -6.196      0.000      -1.756      -0.912
# C(institute_type)[T.INS]                       -0.5112      0.528     -0.969      0.332      -1.545       0.523
# C(institute_type)[T.NBF]                       -0.3107      0.178     -1.746      0.081      -0.659       0.038
# C(institute_type)[T.PUB]                       -0.3546      0.209     -1.697      0.090      -0.764       0.055
# C(institute_type)[T.PVT]                       -0.2617      0.175     -1.492      0.136      -0.605       0.082
# C(institute_type)[T.SRC]                      -48.2581   3.39e+10  -1.43e-09      1.000   -6.64e+10    6.64e+10
# C(institute_type)[T.TEL]                      -17.2314   3099.308     -0.006      0.996   -6091.764    6057.301
# C(marital_status)[T. Married-AF-spouse]         2.8961      0.503      5.753      0.000       1.910       3.883
# C(marital_status)[T. Married-civ-spouse]        2.3389      0.237      9.859      0.000       1.874       2.804
# C(marital_status)[T. Married-spouse-absent]     0.0950      0.201      0.472      0.637      -0.299       0.489
# C(marital_status)[T. Never-married]            -0.3493      0.078     -4.480      0.000      -0.502      -0.197
# C(marital_status)[T. Separated]                 0.0005      0.142      0.003      0.997      -0.279       0.280
# C(marital_status)[T. Widowed]                  -0.2419      0.144     -1.676      0.094      -0.525       0.041
# age                                             0.3480      0.019     18.670      0.000       0.311       0.385
# education_num                                   0.2818      0.008     33.661      0.000       0.265       0.298
# capital_gain                                    0.7329      0.022     33.785      0.000       0.690       0.775
# ===============================================================================================================
# AIC = 25571.174263297573

# %% [markdown]
# Marital status is leading to an decrease in AIC and hence, we will include that in our model.

# %% [markdown]
#  ### Now, that we have our logistic regression model, we will move onto checking if all the assumptions are satisfied.

# %%
### chosen model ###
## calculating vif for quantitative variables ##


y, X = dmatrices('approved ~ age + education_num + capital_gain + capital_loss', data=dupl_mod_data, return_type='dataframe')

#calculate VIF for each explanatory variable

vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['variable'] = X.columns
vif
# Out:
#          VIF       variable
# 0  17.469079      Intercept
# 1   1.012956            age
# 2   1.022198  education_num
# 3   1.034530   capital_gain
# 4   1.000083   capital_loss

# %% [markdown]
# Since all the vif values are around 1, we can safely assume that there is no multicolinearity in the dataset among quantitative variables.

# %% [markdown]
# # Business Problem #

# %% [markdown]
# I think, since ABC is a mobile only bank, their business relies on their credit card customers not defaulting and hence, I believe from the data set, true negative is more important than true positive or the overall accuracy. The higher we can have true negative, the higher are the chances that we will be able to catch an user and not approve their credit card.

# %%
## dividing the data 

z_columns = ['approved','age', 'education_num','capital_gain', 'relationship', 'occupation', 'institute_type', 'inquiry_purpose_code', 'marital_status']

part_data = dupl_mod_data[z_columns]

X = part_data.loc[:,part_data.columns != 'approved']
Y = part_data['approved']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2)

# %%
XY_train = pd.concat([X_train, y_train], axis=1, join='inner')

formula = 'approved ~ age + education_num + capital_gain + C(inquiry_purpose_code) + C(relationship)  + C(occupation) + C(institute_type) + C(marital_status)'


fit = smf.mnlogit(formula=formula, data=XY_train).fit()
fit.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.322478
#          Iterations: 35
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               approved   No. Observations:                25020
# Model:                        MNLogit   Df Residuals:                    24966
# Method:                           MLE   Df Model:                           53
# Date:                Sun, 13 Mar 2022   Pseudo R-squ.:                  0.4140
# Time:                        07:21:44   Log-Likelihood:                -8068.4
# converged:                      False   LL-Null:                       -13769.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===============================================================================================================
#                                  approved=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                      -6.9973      0.490    -14.280      0.000      -7.958      -6.037
# C(inquiry_purpose_code)[T.2.0]                  0.6947      0.298      2.328      0.020       0.110       1.280
# C(inquiry_purpose_code)[T.3.0]                  0.5742      0.547      1.050      0.294      -0.498       1.646
# C(inquiry_purpose_code)[T.4.0]                 -0.6469      1.015     -0.638      0.524      -2.636       1.342
# C(inquiry_purpose_code)[T.5.0]                  1.0122      0.480      2.108      0.035       0.071       1.953
# C(inquiry_purpose_code)[T.6.0]                  0.1288      0.356      0.362      0.717      -0.568       0.826
# C(inquiry_purpose_code)[T.7.0]                  1.7196      0.288      5.965      0.000       1.155       2.285
# C(inquiry_purpose_code)[T.8.0]                  0.7053      0.465      1.517      0.129      -0.206       1.616
# C(inquiry_purpose_code)[T.9.0]                -12.5803   1970.683     -0.006      0.995   -3875.048    3849.888
# C(inquiry_purpose_code)[T.10.0]                -0.3032      0.504     -0.601      0.548      -1.292       0.685
# C(inquiry_purpose_code)[T.11.0]                -0.0793      0.573     -0.138      0.890      -1.203       1.044
# C(inquiry_purpose_code)[T.12.0]                 4.1402      1.467      2.821      0.005       1.264       7.016
# C(inquiry_purpose_code)[T.13.0]                 0.6187      0.285      2.175      0.030       0.061       1.176
# C(inquiry_purpose_code)[T.14.0]                 2.2512      0.311      7.240      0.000       1.642       2.861
# C(inquiry_purpose_code)[T.16.0]                 0.8830      0.292      3.026      0.002       0.311       1.455
# C(inquiry_purpose_code)[T.17.0]                 0.8042      1.033      0.779      0.436      -1.220       2.829
# C(inquiry_purpose_code)[T.18.0]               -23.3891   1.78e+05     -0.000      1.000    -3.5e+05     3.5e+05
# C(inquiry_purpose_code)[T.99.0]                 1.4350      0.286      5.011      0.000       0.874       1.996
# C(relationship)[T. Not-in-family]               0.2420      0.299      0.810      0.418      -0.343       0.827
# C(relationship)[T. Other-relative]             -0.9150      0.268     -3.415      0.001      -1.440      -0.390
# C(relationship)[T. Own-child]                  -1.0565      0.296     -3.564      0.000      -1.637      -0.476
# C(relationship)[T. Unmarried]                  -0.1538      0.313     -0.491      0.623      -0.768       0.460
# C(relationship)[T. Wife]                        0.2393      0.080      3.007      0.003       0.083       0.395
# C(occupation)[T. Armed-Forces]                 -0.1704      1.449     -0.118      0.906      -3.010       2.669
# C(occupation)[T. Craft-repair]                  0.0560      0.085      0.661      0.509      -0.110       0.222
# C(occupation)[T. Exec-managerial]               0.8803      0.082     10.794      0.000       0.720       1.040
# C(occupation)[T. Farming-fishing]              -0.9169      0.147     -6.218      0.000      -1.206      -0.628
# C(occupation)[T. Handlers-cleaners]            -0.6457      0.152     -4.239      0.000      -0.944      -0.347
# C(occupation)[T. Machine-op-inspct]            -0.3704      0.111     -3.338      0.001      -0.588      -0.153
# C(occupation)[T. Other-service]                -1.0337      0.130     -7.924      0.000      -1.289      -0.778
# C(occupation)[T. Priv-house-serv]              -2.0515      1.043     -1.966      0.049      -4.096      -0.006
# C(occupation)[T. Prof-specialty]                0.5478      0.085      6.423      0.000       0.381       0.715
# C(occupation)[T. Protective-serv]               0.4774      0.135      3.525      0.000       0.212       0.743
# C(occupation)[T. Sales]                         0.3214      0.087      3.707      0.000       0.151       0.491
# C(occupation)[T. Tech-support]                  0.5073      0.119      4.269      0.000       0.274       0.740
# C(occupation)[T. Transport-moving]             -0.0127      0.107     -0.118      0.906      -0.223       0.198
# C(institute_type)[T.COB]                        0.9702      0.799      1.214      0.225      -0.597       2.537
# C(institute_type)[T.FOR]                        0.1016      0.423      0.240      0.810      -0.727       0.930
# C(institute_type)[T.HFC]                       -1.2109      0.271     -4.467      0.000      -1.742      -0.680
# C(institute_type)[T.INS]                       -0.2791      0.574     -0.486      0.627      -1.404       0.846
# C(institute_type)[T.NBF]                       -0.1492      0.223     -0.670      0.503      -0.586       0.287
# C(institute_type)[T.PUB]                       -0.1198      0.260     -0.461      0.645      -0.630       0.390
# C(institute_type)[T.PVT]                       -0.1033      0.219     -0.471      0.638      -0.533       0.327
# C(institute_type)[T.SRC]                      -12.9937    821.785     -0.016      0.987   -1623.662    1597.675
# C(institute_type)[T.TEL]                      -30.5240   2.47e+06  -1.23e-05      1.000   -4.85e+06    4.85e+06
# C(marital_status)[T. Married-AF-spouse]         3.2694      0.723      4.525      0.000       1.853       4.686
# C(marital_status)[T. Married-civ-spouse]        2.4300      0.303      8.010      0.000       1.835       3.025
# C(marital_status)[T. Married-spouse-absent]     0.0244      0.263      0.093      0.926      -0.491       0.540
# C(marital_status)[T. Never-married]            -0.2260      0.098     -2.298      0.022      -0.419      -0.033
# C(marital_status)[T. Separated]                 0.1623      0.175      0.928      0.354      -0.181       0.505
# C(marital_status)[T. Widowed]                  -0.0727      0.179     -0.406      0.685      -0.423       0.278
# age                                             0.3649      0.024     15.526      0.000       0.319       0.411
# education_num                                   0.2985      0.011     28.054      0.000       0.278       0.319
# capital_gain                                    0.7195      0.027     26.257      0.000       0.666       0.773
# ===============================================================================================================
# """

# %%
### using the validation set to find the optimized threshold value ####

true_negative = []
true_positive = []
false_negative = []
threshold = []
expected = list(y_val)
predict = list(fit.predict(X_val)[1])

for i in list(np.linspace(0, 1, 100)):
    predicted = list(1 if j > i else 0 for j in predict)
    
    
    cm = confusion_matrix(expected, predicted)


    TP = cm[0][0]
    FN = cm[0][1]
    FP = cm[1][0]
    TN = cm[1][1]
    #print(TP, FN, FP, TN)
    
    # Specificity or true negative rate
    TNR = TN/(TN+FP)
    TPR = TP/(TP+FN)
    FNR = FN/(FN+TP)
    #print(TPR, TNR)
    
    true_negative.append(TNR)
    true_positive.append(TPR)
    false_negative.append(FNR)
    
    threshold.append(i)
    

pt = sns.scatterplot(false_negative, true_positive)
pt.set_xlabel("FNR", fontsize = 20)
pt.set_ylabel("TPR", fontsize = 20)
# Out:
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0, 0.5, 'TPR')

# %% [markdown]
# At the threshold value of 0.2, we optimize our AUC curve above. We will now use this on our testing set.

# %%
expected = list(y_test)
predict = list(fit.predict(X_test)[1])

predicted = list(1 if j > 0.2 else 0 for j in predict)
    
cm = confusion_matrix(expected, predicted)


TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
print(TP, FN, FP, TN)
    
    # Specificity or true negative rate
TNR = TN/(TN+FP)
TPR = TP/(TP+FN)
    #print(TPR, TNR)
    
print(TNR)
print(TPR)
print(cm)
# Out:
# 4543 1467 244 1565
# 0.865118850193477
# 0.7559068219633943
# [[4543 1467]
#  [ 244 1565]]

# %% [markdown]
# From our out of sample testing, we are able to accurately predict 87.2 % of the users that we should decline.
# The accuracy may improve with more sophisticated models but interpretability decreases.

# %% [markdown]
# Since, we have only taken small number of variables, we will not worry about FDR rate. But, in case it is required,
# we can always use the procedure of FDR correction but that will not affect the predictive power of the model, which is our main aim in this problem statement.

# %% [markdown]
# We would need a person's age, education num, capital gain, relationship status, occupation, institute type, marital status and inquiry purpose code to predict whether the user should be declined or not.

# %% [markdown]
# A more sophisticated algorithm or inclusion of interaction terms might gives us better results but that would be
# unnecessary complication in the model since we have already have a high TNR. We will try one of the non-linear method XGB Classifier. Because there are so many variables, adding a penalty to be included in the model might gives us better results.

# %%
dupl_2 = dupl_mod_data.copy(deep = True)


marital_status = pd.get_dummies(dupl_2['marital_status'], drop_first = True)
occupation = pd.get_dummies(dupl_2['occupation'], drop_first = True)
relationship = pd.get_dummies(dupl_2['relationship'], drop_first = True)
inquiry_purpose_code = pd.get_dummies(dupl_2['inquiry_purpose_code'], drop_first = True)
institute_type = pd.get_dummies(dupl_2['institute_type'], drop_first = True)

dupl_2 = dupl_2.loc[:,['age', 'education_num', 'capital_gain', 'approved']]

##mod_data.drop(['workclass', 'education_level', 'marital_status', 'occupation', 'relationship','inquiry_purpose_code', 'institute_type', 'account_type', 'asset_code', 'portfolio_type', 'domain'], axis = 1, inplace = True)

dupl_2 = pd.concat([dupl_2, occupation,relationship, inquiry_purpose_code, institute_type, marital_status], axis = 1)


X = dupl_2.loc[:,dupl_2.columns != 'approved']
Y = dupl_2['approved']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2)

# %%
true_negative = []
true_positive = []
threshold = []
expected = list(y_val)

xgtrain = xgb.DMatrix(X_train, y_train)
xgval = xgb.DMatrix(X_val)

param = {'max_depth':7, 'silent':1}
bst = xgb.train(param, xgtrain, num_boost_round=2)
y_pred = bst.predict(xgval)

for i in list(np.linspace(0, 1, 100)):
    
    pred = [1. if y_cont > i  else 0. for y_cont in y_pred]
    y_true = y_val

    cm = confusion_matrix(y_true, pred)

    TP = cm[0][0]
    FN = cm[0][1]
    FP = cm[1][0]
    TN = cm[1][1]

    # Specificity or true negative rate
    TNR = TN/(TN+FP)
    TPR = TP/(TP+FN)
    
    true_negative.append(TNR)
    true_positive.append(TPR)
    
    threshold.append(i)
    

pt = sns.scatterplot(true_negative, true_positive[::-1])
pt.set_xlabel("TNR", fontsize = 20)
pt.set_ylabel("TPR", fontsize = 20)
# Out:
# [21:57:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0, 0.5, 'TPR')

# %%
#### optimum value of threshold ####

### From the above ROC-AUC curve, we can say that the optimal value of threshold is around 0.20 and 0.3. Trying 0.25. 


xgtest = xgb.DMatrix(X_test)
y_pred = bst.predict(xgtest)

pred = [1. if y_cont > 0.3  else 0. for y_cont in y_pred]
y_true = y_test

cm = confusion_matrix(y_true, pred)

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]

    # Specificity or true negative rate
TNR = TN/(TN+FP)
TPR = TP/(TP+FN)

print("TPR: {}, and TNR: {}".format(TPR, TNR))
# Out:
# TPR: 0.615436129248284, and TNR: 0.9550379198266522

# %% [markdown]
# As we can see, the accuracy of the TNR has gone upto around 92%. We have to very careful with models of such high
# accuracy as it can also be result of over-fitting but we are using an ensemble method along with OOS testing, telling
# us that the predictive power might just be this high and hence, we can use this model in prodcution.

# %% [markdown]
# ### Calculation of credit limit #####

# %% [markdown]
# Since, capital gains is an important part of our model, we can use that to calculate the credit limit. As we can see that we are predicting with high accuracy the TNR rate. We also have a continuous probablity distribution fucntion, which we can use to calculate the credit limit that should be given.
#
# ### credit limit = capital gains * f(probablity to be approved)
#
# The above formula states how I propose the credit limit to be calculated.

# %%
### defining a probablity distribution for all users ###

xgtest = xgb.DMatrix(X)
y_pred = bst.predict(xgtest)

# %% [markdown]
# Since we do not want the credit limit to be too high as compared to capital gains (lower the capital gains, larger the
# chances of the user defaulting on payment. But, if we approve a person, there should be a minimum credit limit. Assuming that is equivalent to 800$. And, we are assuming the function to be an exponential function of the probability predicted.

# %%
mean_v = mod_original['capital_gain'].mean()
std_dev = mod_original['capital_gain'].std()

# %%
## scaling back the capital gains to original values ##

capital_gain = list((i*std_dev)+mean_v for i in list(X['capital_gain']))

credit_limit = list(i*np.exp(j) + 800 for i, j in zip(capital_gain, y_pred))

# %%
mod_data
# Out:
#                        user_id  gender date_of_birth  education_num  \
# 1      519481f1-604d-48b6-aa47       0    1970-01-07             10
# 2      f66fe2c6-53e3-46ce-8321       0    1973-01-06              9
# 4      0e1977f3-3bef-4283-8d0a       0    1986-01-03             10
# 6      27256e97-6bae-4ce6-9b80       0    2001-12-30              9
# 7      745b9022-fe0e-4d8e-8056       0    1996-12-31             10
# ...                        ...     ...           ...            ...
# 44867  009569c0-1eff-467d-8e58       0    2051-01-12              9
# 44868  38609952-497d-49a0-836f       0    2046-01-13             10
# 44869  209ffd58-c716-4302-b613       0    2046-01-13              9
# 44871  11f4ca41-5892-4cc4-84ba       0    2053-01-11             14
# 44872  b2b1c85d-c1ec-4e4c-b47b       0    2053-01-11              9
#
#        capital_gain  capital_loss  hours_per_week  approved  \
# 1         -0.250239     -0.005058        0.650839         0
# 2         -0.250239     -0.005058        0.860096         0
# 4         -0.250239     -0.005058        0.860096         0
# 6         -0.250239     -0.005058       -1.860250         0
# 7         -0.250239     -0.005058        0.860096         0
# ...             ...           ...             ...       ...
# 44867      6.660890     -0.005058       -0.186191         1
# 44868      6.660890     -0.005058       -0.186191         1
# 44869      6.660890     -0.005058       -0.186191         1
# 44871      6.660890     -0.005058        3.161928         1
# 44872      6.660890     -0.005058       -0.186191         1
#
#                                                  address  \
# 1      5022 Rebecca Haven Apt. 258\nThompsonfurt, CT ...
# 2        8780 Brown Loaf Apt. 099\nNorth David, NJ 56510
# 4             935 Burch Divide\nLake Bobbyfurt, VT 14128
# 6      90598 Richardson Mountains Apt. 192\nJohnsonfu...
# 7      28328 Bradley Views Suite 367\nSmithport, AK 5...
# ...                                                  ...
# 44867         692 Ann Viaduct\nSouth Kellyfort, MD 95995
# 44868          70719 Charles Inlet\nKnightside, VA 44156
# 44869        51464 Roberts Trail\nLake Melissa, IN 41238
# 44871  2742 Bell Lake Apt. 219\nEast Ryanmouth, DE 81928
# 44872  2825 Ryan Street Apt. 653\nSouth Curtis, NC 67453
#
#                            email  ... 999  2.0  4.0  19.0  I  M  R  hotmail  \
# 1      johnsontrevor@hotmail.com  ...   0    0    0     0  0  0  1        1
# 2          morganemily@gmail.com  ...   0    0    0     0  0  0  1        0
# 4      shermanmeredith@gmail.com  ...   0    0    0     0  1  0  0        0
# 6           calvin66@hotmail.com  ...   0    0    0     0  0  0  1        1
# 7              bwalker@yahoo.com  ...   0    0    0     0  0  0  1        0
# ...                          ...  ...  ..  ...  ...   ... .. .. ..      ...
# 44867         rirwin@hotmail.com  ...   0    0    0     0  0  0  1        1
# 44868        randerson@price.com  ...   0    0    0     0  0  0  1        0
# 44869      elizabethho@yahoo.com  ...   0    0    0     0  0  0  1        0
# 44871     cooperdustin@gmail.com  ...   0    0    0     0  0  0  1        0
# 44872  martinezchelsea@yahoo.com  ...   0    0    0     0  0  0  1        0
#
#        other  yahoo
# 1          0      0
# 2          0      0
# 4          0      0
# 6          0      0
# 7          0      1
# ...      ...    ...
# 44867      0      0
# 44868      1      0
# 44869      0      1
# 44871      0      0
# 44872      0      1
#
# [39095 rows x 122 columns]

# %%
dupl_2.groupby(['approved'])['approved'].count()
# Out:
# approved
# 0    29781
# 1     9314
# Name: approved, dtype: int64
